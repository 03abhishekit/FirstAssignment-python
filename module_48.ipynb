# %% [markdown]
# Q1: What is the difference between a t-test and a z-test? Provide an example scenario where you would use each type of test.
#
# T-test:Used when the sample size is small (n > 30) or when the population standard deviation is unknown.
# Example: A researcher wants to test whether the mean score of a small class of 20 students is significantly different from the national average.
#
# Z-test:Used when the sample size is large (n ≥ 30) and the population standard deviation is known.
# Example: A company wants to test whether the average height of a large sample of 1000 employees is different from the national average height.
#
#
# Q2: Differentiate between one-tailed and two-tailed tests.
#
# One-tailed test:Tests the direction of the effect (greater than or less than).
# Example: Testing if a new drug is more effective than the current drug.
#
# Two-tailed test:Tests for any difference without specifying the direction.
# Example: Testing if there is a difference in mean scores between two groups without specifying which group will have higher scores.
#
#
# Q3: Explain the concept of Type 1 and Type 2 errors in hypothesis testing. Provide an example scenario for each type of error.
#
# Type 1 error (False Positive):Rejecting the null hypothesis when it is true.
# Example: Concluding that a new drug is effective when it is not.
#
# Type 2 error (False Negative):Failing to reject the null hypothesis when it is false.
# Example: Concluding that a new drug is not effective when it actually is.
#
#
# Q4: Explain Bayes's theorem with an example.
#
# Bayes's Theorem:
#
# P(A∣B)= P(B∣A) ⋅ P(A) / P(B)
#
# Example:
# A medical test for a disease has a 99% accuracy. The disease affects 1% of the population. Calculate the probability that a person has the disease given a positive test result.
#
# P(D∣T)=P(T ∣ D)⋅P(D) / P(T)  ≈ 0.5
#
#
# Q5: What is a confidence interval? How to calculate the confidence interval, explain with an example.
#
# Confidence Interval:
# A range of values within which the population parameter is expected to lie with a certain level of confidence.
#
# Calculation:
#
# CI= xˉ±Z⋅(σ/sqrt(n))
#
# Example:
# For a sample mean of 50, a standard deviation of 5, and a sample size of 30, the 95% confidence interval is:
#
# CI = 50±1.96⋅(530) ≈ (48.21,51.79)
#
# Q6. Use Bayes' Theorem to calculate the probability of an event occurring given prior knowledge of the event's probability and new evidence. Provide a sample problem and solution.
# Sample Problem:
#
# A company knows that 2% of its products are defective. A test that correctly identifies defects 98% of the time is used.
#
# Calculate the probability that a product is defective given a positive test result.
#
# P(D∣T) = P(T∣D) ⋅ P(D) / P(T)) ≈ 0.5
#
# Q7. Calculate the 95% confidence interval for a sample of data with a mean of 50 and a standard deviation of 5. Interpret the results.
#
# Calculation:
#
# C.I. = (48.21,51.79).
#
#
# Q8. What is the margin of error in a confidence interval? How does sample size affect the margin of error? Provide an example of a scenario where a larger sample size would result in a smaller margin of error.
#
# Margin of Error (MOE):
# The maximum expected difference between the true population parameter and the sample estimate.
# Effect of Sample Size:
# Larger sample sizes reduce the margin of error.
# Example:
# Estimating the average income in a city. A larger sample size will provide a more precise estimate with a smaller margin of error.
#
#
# Q9. Calculate the z-score for a data point with a value of 75, a population mean of 70, and a population standard deviation of 5. Interpret the results.
# Calculation:
# z=X−μσ=75−705=1z = \frac{X - \mu}{\sigma} = \frac{75 - 70}{5} = 1z=σX−μ​=575−70​=1Interpretation:
# The data point is 1 standard deviation above the mean.
#
#
#
# Q10. In a study of the effectiveness of a new weight loss drug, a sample of 50 participants lost an average of 6 pounds with a standard deviation of 2.5 pounds. Conduct a hypothesis test to determine if the drug is significantly effective at a 95% confidence level using a t-test.
#
# import scipy.stats as stats
#
# # Given data
# sample_mean = 6
# sample_std_dev = 2.5
# sample_size = 50
# population_mean = 0  # Assuming the null hypothesis is that there is no weight loss
#
# # Calculate the t-statistic
# t_statistic = (sample_mean - population_mean) / (sample_std_dev / (sample_size ** 0.5))
#
# # Calculate the p-value
# p_value = stats.t.sf(abs(t_statistic), df=sample_size-1) * 2
#
# # Compare p-value with significance level
# alpha = 0.05
# if p_value &lt; alpha:
#     result = f"Reject the null hypothesis. p-value: {p_value}"
# else:
#     result = f"Fail to reject the null hypothesis. p-value: {p_value}"
#
# result
#
# Q11. In a survey of 500 people, 65% reported being satisfied with their current job. Calculate the 95% confidence interval for the true proportion of people who are satisfied with their job.
#
# import math
#
# # Given data
# sample_proportion = 0.65
# sample_size = 500
#
# # Calculate the standard error
# standard_error = math.sqrt((sample_proportion * (1 - sample_proportion)) / sample_size)
#
# # Calculate the margin of error
# z_score = 1.96  # for 95% confidence
# margin_of_error = z_score * standard_error
#
# # Calculate the confidence interval
# lower_bound = sample_proportion - margin_of_error
# upper_bound = sample_proportion + margin_of_error
#
# (lower_bound, upper_bound)
#
#
# Q12. A researcher is testing the effectiveness of two different teaching methods on student performance. Sample A has a mean score of 85 with a standard deviation of 6, while sample B has a mean score of 82 with a standard deviation of 5. Conduct a hypothesis test to determine if the two teaching methods have a significant difference in student performance using a t-test with a significance level of 0.01.
#
# Given data
# mean1 = 85
# std_dev1 = 6
# n1 = 30
#
# mean2 = 82
# std_dev2 = 5
# n2 = 40
#
# # Calculate the pooled standard deviation
# pooled_std_dev = math.sqrt(((n1 - 1) * std_dev1**2 + (n2 - 1) * std_dev2**2) / (n1 + n2 - 2))
# standard_error = pooled_std_dev * math.sqrt(1/n1 + 1/n2)
#
# # Calculate the t-statistic
# t_statistic = (mean1 - mean2) / standard_error
#
# # Calculate the p-value
# p_value = stats.t.sf(abs(t_statistic), df=n1 + n2 - 2) * 2
#
# # Compare p-value with significance level
# alpha = 0.01
# if p_value &lt; alpha:
#     result = f"Reject the null hypothesis. p-value: {p_value}"
# else:
#     result = f"Fail to reject the null hypothesis. p-value: {p_value}"
#
# result
#
#
# Q13. A population has a mean of 60 and a standard deviation of 8. A sample of 50 observations has a mean of 65. Calculate the 90% confidence interval for the true population mean.
#
# Given data
# population_mean = 60
# population_std_dev = 8
# sample_mean = 65
# sample_size = 50
#
# # Calculate the standard error
# standard_error = population_std_dev / math.sqrt(sample_size)
#
# # Calculate the margin of error
# z_score = 1.645  # for 90% confidence
# margin_of_error = z_score * standard_error
#
# # Calculate the confidence interval
# lower_bound = sample_mean - margin_of_error
# upper_bound = sample_mean + margin_of_error
#
# (lower_bound, upper_bound)
#
#
# Q14. In a study of the effects of caffeine on reaction time, a sample of 30 participants had an average reaction time of 0.25 seconds with a standard deviation of 0.05 seconds. Conduct a hypothesis test to determine if the caffeine has a significant effect on reaction time at a 90% confidence level using a t-test.
#
# Given data
# sample_mean = 0.25
# sample_std_dev = 0.05
# sample_size = 30
# population_mean = 0  # Assuming the null hypothesis is no effect
#
# # Calculate the t-statistic
# t_statistic = (sample_mean - population_mean) / (sample_std_dev / (sample_size ** 0.5))
#
# # Calculate the p-value
# p_value = stats.t.sf(abs(t_statistic), df=sample_size-1) * 2
#
# # Compare p-value with significance level
# alpha = 0.10
# if p_value &lt; alpha:
#     result = f"Reject the null hypothesis. p-value: {p_value}"
# else:
#     result = f"Fail to reject the null hypothesis. p-value: {p_value}"
#
# result
