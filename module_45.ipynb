# %%
Q1. What is the Probability Density Function?
A Probability Density Function (PDF) describes the likelihood of a random variable to take on a particular value.
For continuous random variables, the PDF is a function that indicates the relative likelihood for this random variable to occur at a given point.
The area under the PDF curve over a given interval represents the probability that the random variable falls within that interval.

Q2. What are the types of Probability Distribution?
There are several types of probability distributions, including:
    Discrete Probability Distributions:
        Binomial Distribution
        Poisson Distribution
        Geometric Distribution
    
    Continuous Probability Distributions:
        Normal Distribution
        Exponential Distribution
        Uniform Distribution
        
        
Q3. Write a Python function to calculate the probability density function of a normal distribution with given mean and standard deviation at a given point.

import math

def normal_pdf(x, mean, std_dev):
    return (1 / (std_dev * math.sqrt(2 * math.pi))) * math.exp(-0.5 * ((x - mean) / std_dev) ** 2)

# Example usage:
print(normal_pdf(1, 0, 1))  # For a standard normal distribution at point x=1


Q4. What are the properties of Binomial Distribution? Give two examples of events where binomial distribution can be applied.
Properties of Binomial Distribution:The number of trials is fixed.Each trial has two possible outcomes: success or failure.
The probability of success is constant for each trial.The trials are independent.

Examples:Tossing a coin 10 times and counting the number of heads.Testing a batch of 100 light bulbs to see how many are defective.


Q5. Generate a random sample of size 1000 from a binomial distribution with a probability of success 0.4 
and plot a histogram of the results using matplotlib.

import numpy as np
import matplotlib.pyplot as plt

# Generate random sample
sample = np.random.binomial(n=10, p=0.4, size=1000)

# Plot histogram
plt.hist(sample, bins=30, edgecolor='black')
plt.title('Binomial Distribution (n=10, p=0.4)')
plt.xlabel('Number of Successes')
plt.ylabel('Frequency')
plt.show()


Q6. Write a Python function to calculate the cumulative distribution function of a Poisson distribution with a given mean at a given point.

import math

def poisson_cdf(k, mean):
    cdf = 0
    for i in range(k + 1):
        cdf += (math.exp(-mean) * mean**i) / math.factorial(i)
    return cdf

# Example usage:
print(poisson_cdf(3, 2))  # For a Poisson distribution with mean=2 at point k=3

Q7. How is the Binomial distribution different from the Poisson distribution?
Binomial Distribution:Used for a fixed number of trials.Each trial has two outcomes: success or failure.
Probability of success is constant.The number of successes in a fixed number of trials is counted.
Poisson Distribution:Used for counting the number of events in a fixed interval of time or space.
Events occur with a known constant mean rate.
The events are independent of each other.The actual number of events in a fixed interval is counted.

Q8. Generate a random sample of size 1000 from a Poisson distribution with mean 5 and calculate the sample mean and variance.

# Generate random sample
sample = np.random.poisson(lam=5, size=1000)

# Calculate sample mean and variance
sample_mean = np.mean(sample)
sample_variance = np.var(sample)

sample_mean, sample_variance


Q9. How are mean and variance related in Binomial distribution and Poisson distribution?
Binomial Distribution:
    Mean (μ) = n⋅p 
    Variance (σ2) = n⋅p⋅(1−p)
    n \cdot p \cdot (1 - p)n⋅p⋅(1−p)Poisson Distribution:Mean (μ\muμ) = λ\lambdaλVariance (σ2\sigma^2σ2) = λ\lambdaλQ10. In a normal distribution with respect to mean position, where does the least frequent data appear?In a normal distribution, the least frequent data appears in the tails of the distribution, farthest from the mean. These are the values that are several standard deviations away from the mean.
